# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='pink', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2098.095333376173">
# ([<matplotlib.axis.XTick at 0x1a0bbc1ba20>,
#   <matplotlib.axis.XTick at 0x1a0bc27df28>,
#   <matplotlib.axis.XTick at 0x1a0bc27d048>,
#   <matplotlib.axis.XTick at 0x1a0bc04b358>,
#   <matplotlib.axis.XTick at 0x1a0bc04b7b8>,
#   <matplotlib.axis.XTick at 0x1a0bc04bc88>,
#   <matplotlib.axis.XTick at 0x1a0bc04b198>,
#   <matplotlib.axis.XTick at 0x1a0bc0543c8>,
#   <matplotlib.axis.XTick at 0x1a0bc054898>,
#   <matplotlib.axis.XTick at 0x1a0bc054d68>,
#   <matplotlib.axis.XTick at 0x1a0bc05b278>,
#   <matplotlib.axis.XTick at 0x1a0bc05b748>,
#   <matplotlib.axis.XTick at 0x1a0bc05bc18>,
#   <matplotlib.axis.XTick at 0x1a0bc064160>,
#   <matplotlib.axis.XTick at 0x1a0bc0645f8>,
#   <matplotlib.axis.XTick at 0x1a0bc05b828>,
#   <matplotlib.axis.XTick at 0x1a0bc054be0>,
#   <matplotlib.axis.XTick at 0x1a0bc0649b0>,
#   <matplotlib.axis.XTick at 0x1a0bc0640f0>,
#   <matplotlib.axis.XTick at 0x1a0bc06c278>,
#   <matplotlib.axis.XTick at 0x1a0bc06c748>,
#   <matplotlib.axis.XTick at 0x1a0bc06cc18>,
#   <matplotlib.axis.XTick at 0x1a0bc074160>,
#   <matplotlib.axis.XTick at 0x1a0bc0745f8>,
#   <matplotlib.axis.XTick at 0x1a0bc074ac8>,
#   <matplotlib.axis.XTick at 0x1a0bc074e80>,
#   <matplotlib.axis.XTick at 0x1a0bc06cb70>,
#   <matplotlib.axis.XTick at 0x1a0bc064898>,
#   <matplotlib.axis.XTick at 0x1a0bc07c2e8>,
#   <matplotlib.axis.XTick at 0x1a0bc07c860>,
#   <matplotlib.axis.XTick at 0x1a0bc07cdd8>,
#   <matplotlib.axis.XTick at 0x1a0bc083390>,
#   <matplotlib.axis.XTick at 0x1a0bc083908>,
#   <matplotlib.axis.XTick at 0x1a0bc083e80>,
#   <matplotlib.axis.XTick at 0x1a0bc08c438>,
#   <matplotlib.axis.XTick at 0x1a0bc083860>,
#   <matplotlib.axis.XTick at 0x1a0bc0647b8>,
#   <matplotlib.axis.XTick at 0x1a0bc08c8d0>,
#   <matplotlib.axis.XTick at 0x1a0bc08ce48>,
#   <matplotlib.axis.XTick at 0x1a0bc091400>,
#   <matplotlib.axis.XTick at 0x1a0bc091978>,
#   <matplotlib.axis.XTick at 0x1a0bc091ef0>,
#   <matplotlib.axis.XTick at 0x1a0bc0984a8>,
#   <matplotlib.axis.XTick at 0x1a0bc098a20>,
#   <matplotlib.axis.XTick at 0x1a0bc098e80>,
#   <matplotlib.axis.XTick at 0x1a0bc091a58>,
#   <matplotlib.axis.XTick at 0x1a0bc083780>,
#   <matplotlib.axis.XTick at 0x1a0bc04bc50>,
#   <matplotlib.axis.XTick at 0x1a0bc0a15f8>,
#   <matplotlib.axis.XTick at 0x1a0bc0a1b70>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(227.8333221409056, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/pretty_pink_avg_state_rain.png")
plt.show()
